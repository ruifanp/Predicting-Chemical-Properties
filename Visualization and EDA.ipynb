# %%
import pandas as pd
import numpy as np

from ase import Atoms
import ase.visualize

import sklearn
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
structures = pd.read_csv("data/structures.csv")

# %% [markdown]
# ### Visualization of molecules

# %%
def view3d(df, struct_name):
    """
    Returns: A 3D representation of the molecule
    df: pandas dataframe containing structures
    struct_name: nolecule_name to be viewed
    """
    molecule_df = df[df['molecule_name'] == struct_name]
    atoms = molecule_df['atom'].values.tolist()
    coords = molecule_df[['x', 'y', 'z']].values.tolist()
    
    molecule = Atoms(symbols=atoms, positions=coords)
    
    print("Molecule name: {}".format(struct_name))
    print("Atoms: {}".format(atoms))
    return ase.visualize.view(molecule, viewer="x3d")

# %%
#Example molecule
view3d(structures, "dsgdb9nsd_002116")
# Out:
# Molecule name: dsgdb9nsd_002116
# Atoms: ['O', 'C', 'N', 'C', 'C', 'C', 'O', 'H', 'H', 'H']
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="-0.02 -0.04 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.01 1.16 0.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.12 2.01 0.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.71 3.34 0.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.63 3.49 0.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.22 2.15 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.37 1.78 -0.02">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.07 1.69 0.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.47 4.12 0.04">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.18 4.42 0.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# ### EDA

# %%
train.head(10)
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
# 5   5  dsgdb9nsd_000001             2             3  2JHH
# 6   6  dsgdb9nsd_000001             2             4  2JHH
# 7   7  dsgdb9nsd_000001             3             0  1JHC
# 8   8  dsgdb9nsd_000001             3             4  2JHH
# 9   9  dsgdb9nsd_000001             4             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074
# 5                  -11.2541
# 6                  -11.2548
# 7                   84.8093
# 8                  -11.2543
# 9                   84.8095

# %%
structures.head(15)
# Out:
#        molecule_name  atom_index atom         x         y         z
# 0   dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1   dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2   dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3   dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4   dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# 5   dsgdb9nsd_000002           0    N -0.040426  1.024108  0.062564
# 6   dsgdb9nsd_000002           1    H  0.017257  0.012545 -0.027377
# 7   dsgdb9nsd_000002           2    H  0.915789  1.358745 -0.028758
# 8   dsgdb9nsd_000002           3    H -0.520278  1.343532 -0.775543
# 9   dsgdb9nsd_000003           0    O -0.034360  0.977540  0.007602
# 10  dsgdb9nsd_000003           1    H  0.064766  0.020572  0.001535
# 11  dsgdb9nsd_000003           2    H  0.871790  1.300792  0.000693
# 12  dsgdb9nsd_000004           0    C  0.599539  0.000000  1.000000
# 13  dsgdb9nsd_000004           1    C -0.599539  0.000000  1.000000
# 14  dsgdb9nsd_000004           2    H -1.661639  0.000000  1.000000

# %%
test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4659076  dsgdb9nsd_000004             2             0  2JHC
# 1  4659077  dsgdb9nsd_000004             2             1  1JHC
# 2  4659078  dsgdb9nsd_000004             2             3  3JHH
# 3  4659079  dsgdb9nsd_000004             3             0  1JHC
# 4  4659080  dsgdb9nsd_000004             3             1  2JHC

# %%
print("Shape of train data: {}".format(train.shape))
print("Shape of test data: {}".format(test.shape))
print("Types of atoms: {}".format(structures['atom'].unique()))
print("Coupling types: {}".format(train['type'].unique()))
print("Number of molecules in training data: {}".format(train['molecule_name'].nunique()))
print("Number of molecules in test data: {}".format(test['molecule_name'].nunique()))
# Out:
# Shape of train data: (4659076, 6)
# Shape of test data: (2505190, 5)
# Types of atoms: ['C' 'H' 'N' 'O' 'F']
# Coupling types: ['1JHC' '2JHH' '1JHN' '2JHN' '2JHC' '3JHH' '3JHC' '3JHN']
# Number of molecules in training data: 85012
# Number of molecules in test data: 45777

# %%
#Average scalar coupling constant by type
train.groupby("type")['scalar_coupling_constant'].agg(['mean', 'std', 'count'])
# Out:
#            mean        std    count
# type
# 1JHC  94.973472  18.290334   709133
# 1JHN  47.492087  10.897996    43680
# 2JHC  -0.273447   4.520720  1140867
# 2JHH -10.283040   3.983509   377988
# 2JHN   3.125678   3.676290   119059
# 3JHC   3.688640   3.075859  1511207
# 3JHH   4.771004   3.706132   590529
# 3JHN   0.991046   1.320717   166613

# %% [markdown]
# ### Merging dataframes

# %%
def merge_df_with_structure(df, structure):
    """
    Returns: df containing the training/testing data with structural data
    df: train or test set, as given in the csv file
    structure: structures df as given in the csv file
    """
    df = pd.merge(df, structures, how='left', 
                 left_on = ['molecule_name', 'atom_index_0'],
                 right_on = ['molecule_name', 'atom_index'])

    df =  df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': 'atom_0', 'x': 'atom_index_0_x', 'y': 'atom_index_0_y', 'z': 'atom_index_0_z'})

    df = pd.merge(df, structures, how='left', 
                 left_on = ['molecule_name', 'atom_index_1'],
                 right_on = ['molecule_name', 'atom_index'])

    df =  df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': 'atom_1', 'x': 'atom_index_1_x', 'y': 'atom_index_1_y', 'z': 'atom_index_1_z'})
    
    #Reorder columns so that scalar coupling constant is in the back, if test set
    try:
        cols = df.columns.tolist()
        cols.append(cols.pop(cols.index('scalar_coupling_constant')))
        df = df.reindex(columns=cols)
    except:
        pass
    
    return df

# %%
trainx = merge_df_with_structure(train, structures)
testx= merge_df_with_structure(test, structures)

# %%
trainx.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC      H
# 1   1  dsgdb9nsd_000001             1             2  2JHH      H
# 2   2  dsgdb9nsd_000001             1             3  2JHH      H
# 3   3  dsgdb9nsd_000001             1             4  2JHH      H
# 4   4  dsgdb9nsd_000001             2             0  1JHC      H
#
#    atom_index_0_x  atom_index_0_y  atom_index_0_z atom_1  atom_index_1_x  \
# 0        0.002150       -0.006031        0.001976      C       -0.012698
# 1        0.002150       -0.006031        0.001976      H        1.011731
# 2        0.002150       -0.006031        0.001976      H       -0.540815
# 3        0.002150       -0.006031        0.001976      H       -0.523814
# 4        1.011731        1.463751        0.000277      C       -0.012698
#
#    atom_index_1_y  atom_index_1_z  scalar_coupling_constant
# 0        1.085804        0.008001                   84.8076
# 1        1.463751        0.000277                  -11.2570
# 2        1.447527       -0.876644                  -11.2548
# 3        1.437933        0.906397                  -11.2543
# 4        1.085804        0.008001                   84.8074

# %%
testx.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0  4659076  dsgdb9nsd_000004             2             0  2JHC      H
# 1  4659077  dsgdb9nsd_000004             2             1  1JHC      H
# 2  4659078  dsgdb9nsd_000004             2             3  3JHH      H
# 3  4659079  dsgdb9nsd_000004             3             0  1JHC      H
# 4  4659080  dsgdb9nsd_000004             3             1  2JHC      H
#
#    atom_index_0_x  atom_index_0_y  atom_index_0_z atom_1  atom_index_1_x  \
# 0       -1.661639             0.0             1.0      C        0.599539
# 1       -1.661639             0.0             1.0      C       -0.599539
# 2       -1.661639             0.0             1.0      H        1.661639
# 3        1.661639             0.0             1.0      C        0.599539
# 4        1.661639             0.0             1.0      C       -0.599539
#
#    atom_index_1_y  atom_index_1_z
# 0             0.0             1.0
# 1             0.0             1.0
# 2             0.0             1.0
# 3             0.0             1.0
# 4             0.0             1.0

# %% [markdown]
# ### Encoding categorical variables

# %%
#One Hot Encoding
dd = trainx.copy()

#Drop columns we don't want to use for prediction
dd = dd.drop(['id', 'molecule_name'], axis=1)


col_transformer = make_column_transformer(
                (['type', 'atom_0', 'atom_1'], OneHotEncoder()),
                remainder='passthrough')

transformed_data = col_transformer.fit_transform(dd)

print("Types of 'atom_0': {}".format(dd['atom_0'].unique()))
print("Types of 'atom_1': {}".format(dd['atom_1'].unique()))
print("Types of 'interactions': {}".format(dd['type'].unique()))

transformed_data[3]
# Out:
# C:\Users\Ruifan\Anaconda3\envs\chem\lib\site-packages\sklearn\compose\_column_transformer.py:778: DeprecationWarning: `make_column_transformer` now expects (transformer, columns) as input tuples instead of (columns, transformer). This has been introduced in v0.20.1. `make_column_transformer` will stop accepting the deprecated (columns, transformer) order in v0.22.
#   warnings.warn(message, DeprecationWarning)
# Types of 'atom_0': ['H']
# Types of 'atom_1': ['C' 'H' 'N']
# Types of 'interactions': ['1JHC' '2JHH' '1JHN' '2JHN' '2JHC' '3JHH' '3JHC' '3JHN']
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  4.00000000e+00,  2.15041600e-03, -6.03131760e-03,
#         1.97612040e-03, -5.23813635e-01,  1.43793264e+00,  9.06397294e-01,
#        -1.12543000e+01])

# %% [markdown]
# ### Dummy Perceptron

# %%
def evaluate(predicted, labels):
    """
    Returns: log of mean absolute error (right now overall, not seperated by type and averaged)
    predicted: list of predicted scalar coupling constants
    labels: list actual scalar coupling constants
    """
    n = len(predicted)
    sum_errs = sum(abs(predicted - labels))
    score = np.log(1/n * sum_errs)
    #print(sum_errs/n)
    return score

# %%
#Split train and test 
dat1 = transformed_data.copy()

X = [i[:-1] for i in dat1]
Y = [i[-1] for i in dat1]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=4)

# %%
per = MLPRegressor(hidden_layer_sizes=(100,), verbose=True, early_stopping=True)
per.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 40.27422803
# Validation score: 0.956427
# Iteration 2, loss = 26.33429927
# Validation score: 0.957564
# Iteration 3, loss = 25.98846717
# Validation score: 0.958075
# Iteration 4, loss = 25.45313398
# Validation score: 0.958930
# Iteration 5, loss = 24.99589990
# Validation score: 0.959802
# Iteration 6, loss = 24.75735868
# Validation score: 0.959134
# Iteration 7, loss = 24.55670222
# Validation score: 0.959781
# Iteration 8, loss = 24.40324216
# Validation score: 0.960544
# Iteration 9, loss = 24.28880727
# Validation score: 0.960663
# Iteration 10, loss = 24.15500615
# Validation score: 0.960541
# Iteration 11, loss = 24.06024574
# Validation score: 0.961091
# Iteration 12, loss = 23.97122261
# Validation score: 0.961314
# Iteration 13, loss = 23.88877112
# Validation score: 0.960856
# Iteration 14, loss = 23.82270358
# Validation score: 0.961468
# Iteration 15, loss = 23.75602860
# Validation score: 0.961661
# Iteration 16, loss = 23.69897583
# Validation score: 0.961397
# Iteration 17, loss = 23.65112445
# Validation score: 0.961742
# Iteration 18, loss = 23.59193740
# Validation score: 0.961092
# Iteration 19, loss = 23.53150858
# Validation score: 0.961837
# Iteration 20, loss = 23.46775838
# Validation score: 0.962117
# Iteration 21, loss = 23.40865839
# Validation score: 0.962175
# Iteration 22, loss = 23.32612994
# Validation score: 0.962192
# Iteration 23, loss = 23.28259237
# Validation score: 0.962027
# Iteration 24, loss = 23.24156606
# Validation score: 0.962019
# Iteration 25, loss = 23.20183440
# Validation score: 0.962620
# Iteration 26, loss = 23.16082727
# Validation score: 0.962367
# Iteration 27, loss = 23.12450759
# Validation score: 0.962241
# Iteration 28, loss = 23.09674318
# Validation score: 0.961648
# Iteration 29, loss = 23.07546261
# Validation score: 0.962709
# Iteration 30, loss = 23.04373462
# Validation score: 0.962297
# Iteration 31, loss = 23.00999309
# Validation score: 0.962714
# Iteration 32, loss = 22.97799715
# Validation score: 0.962886
# Iteration 33, loss = 22.94790366
# Validation score: 0.962774
# Iteration 34, loss = 22.91360493
# Validation score: 0.962886
# Iteration 35, loss = 22.89548814
# Validation score: 0.962718
# Iteration 36, loss = 22.85397918
# Validation score: 0.962982
# Iteration 37, loss = 22.82674333
# Validation score: 0.963081
# Iteration 38, loss = 22.81313023
# Validation score: 0.962996
# Iteration 39, loss = 22.78402634
# Validation score: 0.962627
# Iteration 40, loss = 22.76835978
# Validation score: 0.962645
# Iteration 41, loss = 22.74424533
# Validation score: 0.963086
# Iteration 42, loss = 22.73140634
# Validation score: 0.962416
# Iteration 43, loss = 22.70483330
# Validation score: 0.963003
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=True, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=200, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=True, warm_start=False)

# %%
y_predicted = per.predict(x_test)

evaluate(y_predicted, y_test)
# Out:
# 1.2857512714656132

# %%
# %reset array
per = MLPRegressor(hidden_layer_sizes=(500,), verbose=True, early_stopping=True)
per.fit(x_train, y_train)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Iteration 1, loss = 32.65077730
# Validation score: 0.958453
# Iteration 2, loss = 24.63160324
# Validation score: 0.960591
# Iteration 3, loss = 23.77583625
# Validation score: 0.961519
# Iteration 4, loss = 23.21486655
# Validation score: 0.962707
# Iteration 5, loss = 22.78898685
# Validation score: 0.963156
# Iteration 6, loss = 22.43755923
# Validation score: 0.962586
# Iteration 7, loss = 22.12149855
# Validation score: 0.963266
# Iteration 8, loss = 21.86189093
# Validation score: 0.964497
# Iteration 9, loss = 21.61087560
# Validation score: 0.965053
# Iteration 10, loss = 21.40896095
# Validation score: 0.965306
# Iteration 11, loss = 21.21997743
# Validation score: 0.965351
# Iteration 12, loss = 21.04677274
# Validation score: 0.964615
# Iteration 13, loss = 20.91852989
# Validation score: 0.965384
# Iteration 14, loss = 20.77152363
# Validation score: 0.966295
# Iteration 15, loss = 20.66044098
# Validation score: 0.964792
# Iteration 16, loss = 20.53873026
# Validation score: 0.965199
# Iteration 17, loss = 20.42629496
# Validation score: 0.966148
# Iteration 18, loss = 20.33779385
# Validation score: 0.966810
# Iteration 19, loss = 20.24484753
# Validation score: 0.967005
# Iteration 20, loss = 20.17213109
# Validation score: 0.967005
# Iteration 21, loss = 20.09543518
# Validation score: 0.966306
# Iteration 22, loss = 20.03403706
# Validation score: 0.966951
# Iteration 23, loss = 19.97624796
# Validation score: 0.966513
# Iteration 24, loss = 19.93020441
# Validation score: 0.967582
# Iteration 25, loss = 19.87154450
# Validation score: 0.967367
# Iteration 26, loss = 19.82053753
# Validation score: 0.967314
# Iteration 27, loss = 19.77457373
# Validation score: 0.967129
# Iteration 28, loss = 19.73953485
# Validation score: 0.967581
# Iteration 29, loss = 19.69193893
# Validation score: 0.966683
# Iteration 30, loss = 19.67043726
# Validation score: 0.967850
# Iteration 31, loss = 19.62355833
# Validation score: 0.967518
# Iteration 32, loss = 19.58005755
# Validation score: 0.968038
# Iteration 33, loss = 19.54335241
# Validation score: 0.967741
# Iteration 34, loss = 19.51012218
# Validation score: 0.968105
# Iteration 35, loss = 19.47556489
# Validation score: 0.967900
# Iteration 36, loss = 19.43187657
# Validation score: 0.968240
# Iteration 37, loss = 19.41289986
# Validation score: 0.968301
# Iteration 38, loss = 19.37645456
# Validation score: 0.967901
# Iteration 39, loss = 19.33527836
# Validation score: 0.968056
# Iteration 40, loss = 19.31486440
# Validation score: 0.968093
# Iteration 41, loss = 19.28574558
# Validation score: 0.968447
# Iteration 42, loss = 19.24103076
# Validation score: 0.968436
# Iteration 43, loss = 19.21090943
# Validation score: 0.968164
# Iteration 44, loss = 19.19985435
# Validation score: 0.967999
# Iteration 45, loss = 19.15515859
# Validation score: 0.968559
# Iteration 46, loss = 19.12041319
# Validation score: 0.968855
# Iteration 47, loss = 19.11002260
# Validation score: 0.967861
# Iteration 48, loss = 19.08279862
# Validation score: 0.968421
# Iteration 49, loss = 19.05282135
# Validation score: 0.968782
# Iteration 50, loss = 19.03161460
# Validation score: 0.968710
# Iteration 51, loss = 19.00932298
# Validation score: 0.969053
# Iteration 52, loss = 18.99169420
# Validation score: 0.968908
# Iteration 53, loss = 18.97489194
# Validation score: 0.968791
# Iteration 54, loss = 18.94902484
# Validation score: 0.968119
# Iteration 55, loss = 18.94980000
# Validation score: 0.968818
# Iteration 56, loss = 18.90561042
# Validation score: 0.968778
# Iteration 57, loss = 18.90579027
# Validation score: 0.968778
# Iteration 58, loss = 18.86840705
# Validation score: 0.969010
# Iteration 59, loss = 18.85720432
# Validation score: 0.968875
# Iteration 60, loss = 18.84588190
# Validation score: 0.969015
# Iteration 61, loss = 18.82913505
# Validation score: 0.968323
# Iteration 62, loss = 18.81666622
# Validation score: 0.968354
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=True, epsilon=1e-08,
#              hidden_layer_sizes=(500,), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=200, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=True, warm_start=False)

# %%
y_predicted = per.predict(x_test)

evaluate(y_predicted, y_test)
# Out:
# 1.2094644152358631

# %%
# %reset array
per = MLPRegressor(hidden_layer_sizes=(500,500,200,), verbose=True, early_stopping=True)
per.fit(x_train, y_train)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Iteration 1, loss = 25.24158856
# Validation score: 0.965322
# Iteration 2, loss = 20.50802431
# Validation score: 0.967917
# Iteration 3, loss = 18.90822239
# Validation score: 0.970138
# Iteration 4, loss = 17.98921846
# Validation score: 0.969790
# Iteration 5, loss = 17.36310849
# Validation score: 0.971697
# Iteration 6, loss = 16.81971084
# Validation score: 0.972639
# Iteration 7, loss = 16.35648575
# Validation score: 0.973469
# Iteration 8, loss = 15.98537453
# Validation score: 0.974043
# Iteration 9, loss = 15.59875422
# Validation score: 0.974392
# Iteration 10, loss = 15.35332404
# Validation score: 0.975274
# Iteration 11, loss = 15.06697804
# Validation score: 0.974850
# Iteration 12, loss = 14.82259862
# Validation score: 0.975699
# Iteration 13, loss = 14.63838757
# Validation score: 0.975386
# Iteration 14, loss = 14.44716527
# Validation score: 0.975974
# Iteration 15, loss = 14.27406231
# Validation score: 0.976894
# Iteration 16, loss = 14.10540499
# Validation score: 0.976853
# Iteration 17, loss = 13.90984701
# Validation score: 0.977241
# Iteration 18, loss = 13.82283679
# Validation score: 0.976511
# Iteration 19, loss = 13.66627447
# Validation score: 0.977337
# Iteration 20, loss = 13.54012537
# Validation score: 0.977481
# Iteration 21, loss = 13.42386496
# Validation score: 0.977835
# Iteration 22, loss = 13.32138037
# Validation score: 0.977156
# Iteration 23, loss = 13.23499566
# Validation score: 0.977153
# Iteration 24, loss = 13.11388153
# Validation score: 0.977310
# Iteration 25, loss = 12.99824648
# Validation score: 0.977183
# Iteration 26, loss = 12.88797496
# Validation score: 0.978329
# Iteration 27, loss = 12.80316667
# Validation score: 0.978291
# Iteration 28, loss = 12.74937480
# Validation score: 0.978408
# Iteration 29, loss = 12.66340622
# Validation score: 0.978408
# Iteration 30, loss = 12.54150251
# Validation score: 0.977442
# Iteration 31, loss = 12.52062525
# Validation score: 0.978769
# Iteration 32, loss = 12.41855278
# Validation score: 0.979048
# Iteration 33, loss = 12.38413979
# Validation score: 0.978775
# Iteration 34, loss = 12.26717769
# Validation score: 0.977665
# Iteration 35, loss = 12.26954553
# Validation score: 0.978403
# Iteration 36, loss = 12.19394652
# Validation score: 0.978743
# Iteration 37, loss = 12.09992366
# Validation score: 0.979247
# Iteration 38, loss = 12.05434245
# Validation score: 0.979217
# Iteration 39, loss = 12.00848696
# Validation score: 0.979201
# Iteration 40, loss = 11.93775392
# Validation score: 0.979577
# Iteration 41, loss = 11.88826942
# Validation score: 0.979409
# Iteration 42, loss = 11.85309096
# Validation score: 0.979635
# Iteration 43, loss = 11.78526756
# Validation score: 0.979755
# Iteration 44, loss = 11.72923252
# Validation score: 0.979286
# Iteration 45, loss = 11.68603230
# Validation score: 0.979681
# Iteration 46, loss = 11.63336170
# Validation score: 0.979384
# Iteration 47, loss = 11.61510080
# Validation score: 0.979202
# Iteration 48, loss = 11.54023854
# Validation score: 0.979978
# Iteration 49, loss = 11.51379530
# Validation score: 0.979775
# Iteration 50, loss = 11.48101746
# Validation score: 0.978820
# Iteration 51, loss = 11.45998227
# Validation score: 0.980178
# Iteration 52, loss = 11.40151525
# Validation score: 0.978742
# Iteration 53, loss = 11.37773928
# Validation score: 0.980288
# Iteration 54, loss = 11.33120114
# Validation score: 0.979508
# Iteration 55, loss = 11.25549872
# Validation score: 0.979419
# Iteration 56, loss = 11.21075950
# Validation score: 0.979512
# Iteration 57, loss = 11.18046610
# Validation score: 0.980338
# Iteration 58, loss = 11.17728677
# Validation score: 0.979785
# Iteration 59, loss = 11.15309438
# Validation score: 0.980597
# Iteration 60, loss = 11.11066192
# Validation score: 0.979689
# Iteration 61, loss = 11.06525169
# Validation score: 0.980388
# Iteration 62, loss = 11.00817883
# Validation score: 0.980280
# Iteration 63, loss = 11.00549910
# Validation score: 0.980569
# Iteration 64, loss = 10.96513615
# Validation score: 0.980515
# Iteration 65, loss = 10.95434023
# Validation score: 0.980498
# Iteration 66, loss = 10.90246596
# Validation score: 0.980400
# Iteration 67, loss = 10.87590877
# Validation score: 0.980197
# Iteration 68, loss = 10.86576631
# Validation score: 0.980603
# Iteration 69, loss = 10.84443312
# Validation score: 0.980264
# Iteration 70, loss = 10.81864231
# Validation score: 0.980881
# Iteration 71, loss = 10.77228567
# Validation score: 0.980139
# Iteration 72, loss = 10.74402052
# Validation score: 0.980180
# Iteration 73, loss = 10.71952643
# Validation score: 0.980144
# Iteration 74, loss = 10.69927486
# Validation score: 0.980454
# Iteration 75, loss = 10.67741286
# Validation score: 0.979954
# Iteration 76, loss = 10.66738105
# Validation score: 0.980342
# Iteration 77, loss = 10.60256330
# Validation score: 0.980507
# Iteration 78, loss = 10.62288297
# Validation score: 0.980324
# Iteration 79, loss = 10.61093510
# Validation score: 0.980672
# Iteration 80, loss = 10.56961931
# Validation score: 0.980680
# Iteration 81, loss = 10.54515175
# Validation score: 0.980751
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=True, epsilon=1e-08,
#              hidden_layer_sizes=(500, 500, 200), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=200, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=True, warm_start=False)

# %%
y_predicted = per.predict(x_test)

evaluate(y_predicted, y_test)
# Out:
# 0.9701033780590341
